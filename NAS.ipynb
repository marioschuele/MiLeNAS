# %%
# !git clone https://github.com/marioschuele/MiLeNAS
# Out:
# Cloning into 'MiLeNAS'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 77 (delta 38), reused 71 (delta 32), pack-reused 0
# Unpacking objects: 100% (77/77), 1.26 MiB | 9.45 MiB/s, done.

# %%
# !cd MiLeNAS

# %%
# !nvidia-smi
# Out:
# Sun Apr  9 06:25:35 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install graphviz
# !pip install ptflops
# !pip install wandb
# !pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ptflops: filename=ptflops-0.7-py3-none-any.whl size=11076 sha256=6a0cee431c5c9b18de2337289e8f333b15af5e558b5c8caace5109dcec45ae83
#   Stored in directory: /root/.cache/pip/wheels/b9/54/3b/f84523431ce82e08462644d279c0e13a51a00236e237e6bc7e
# Successfully built ptflops
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 52.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 22.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !wandb login
#wandb API: 37feacd21286db2904d6baf9275dc9b32df5b2c5
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download yuweisunut/sidd-segmented-intrusion-detection-dataset
# !unzip sidd-segmented-intrusion-detection-dataset
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/463.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/464.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/465.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/466.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/467.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/468.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/469.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/47.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/470.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/471.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/472.jpg
#   inflating: SIDD/n056/pcap/n056_20191205_000002_1/dataset/benign/473.jpg
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python ./MiLeNAS/search_algorithm/train_milenas.py --seed 0 --epochs 70 --batch_size 512 --layers 4 --model_path saved_models --learning_rate 0.025 --weight_decay 0.0003 --early_stopping 1
# Out:
# Experiment dir : search-EXP-20230511-201522
# wandb: Currently logged in as: mario-schuele (team-mario). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.2
# wandb: Run data is saved locally in /content/wandb/run-20230511_201523-4o8qzg2q
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run r0-e70-lr0.025-l(1,1)
# wandb: ⭐️ View project at https://wandb.ai/team-mario/uncategorized
# wandb: 🚀 View run at https://wandb.ai/team-mario/uncategorized/runs/4o8qzg2q
# 2023-05-11 20:15:24.221 INFO:	gpus = [0]
# 2023-05-11 20:15:24.245 INFO:	gpu device = 0
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 sh MiLeNAS/evaluation/run_eval_cifar10.sh "0" GDAS_MIXED_LEVEL2 6 0.030 saved_models

# %%
# !python MiLeNAS/visualization/visualize.py GDAS_MIXED_LEVEL2

# %%
# !CUDA_VISIBLE_DEVICES=0 ./evaluation/run_eval_cifar10.sh --batch_size 16 --gpu 0 --epochs 5 --learning_rate 0.030 --model_path saved_models
